# %%
import pandas as pd
import boto3
import os

# %%
# set up S3 client
s3 = boto3.client('s3')

# list all the CSV files in the S3 bucket
bucket_name = 'sector-classification'
prefix = 'Bert_Results_Africa_2015_2023/aggregated_results/'
objects = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)['Contents']
files = [obj['Key'] for obj in objects if obj['Key'].endswith('.csv')]

# %%
files[

# %%
combined_df
# Out:
#    country  Month  Year  consumer goods average_tone  \
# 57      ZI     10  2022                       -0.501
# 57      ZI      9  2022                        2.571
# 57      ZI      8  2022                        0.098
# 57      ZI      7  2022                        1.705
# 57      ZI      6  2022                        3.218
# ..     ...    ...   ...                          ...
# 0       AG      7  2015                       -0.067
# 0       AG      6  2015                        0.086
# 0       AG      5  2015                        1.410
# 0       AG      4  2015                        1.881
# 0       AG      3  2015                        0.823
#
#     extractives & minerals processing average_tone  financials average_tone  \
# 57                                           0.202                   -0.355
# 57                                           0.445                   -0.616
# 57                                           0.073                   -0.011
# 57                                           1.394                    0.436
# 57                                           0.969                    0.326
# ..                                             ...                      ...
# 0                                           -0.563                    0.987
# 0                                           -0.909                    1.479
# 0                                           -0.595                    0.912
# 0                                           -0.309                    1.223
# 0                                           -1.748                    1.375
#
#     food & beverage average_tone  health care average_tone  \
# 57                        -0.200                    -1.010
# 57                         0.249                    -1.752
# 57                         0.300                    -1.920
# 57                         0.592                    -1.667
# 57                         0.145                    -2.150
# ..                           ...                       ...
# 0                          1.106                    -2.343
# 0                          0.322                    -2.153
# 0                          0.819                    -1.368
# 0                          1.242                    -2.338
# 0                          0.842                    -2.807
#
#     infrastructure average_tone  \
# 57                       -0.064
# 57                       -0.177
# 57                        0.397
# 57                       -0.557
# 57                       -0.225
# ..                          ...
# 0                        -0.049
# 0                        -0.103
# 0                        -2.071
# 0                         0.086
# 0                        -0.334
#
#     renewable resources & alternative energy average_tone  ...  \
# 57                                             -0.805      ...
# 57                                             -0.869      ...
# 57                                             -1.334      ...
# 57                                              0.103      ...
# 57                                             -1.024      ...
# ..                                                ...      ...
# 0                                              -0.825      ...
# 0                                              -0.603      ...
# 0                                               0.786      ...
# 0                                              -0.983      ...
# 0                                               0.410      ...
#
#     food & beverage group_size  health care group_size  \
# 57                       206.0                   960.0
# 57                       169.0                  1042.0
# 57                       178.0                  1076.0
# 57                       155.0                   874.0
# 57                       183.0                   826.0
# ..                         ...                     ...
# 0                         66.0                   725.0
# 0                         71.0                   680.0
# 0                         70.0                   671.0
# 0                         60.0                   637.0
# 0                         76.0                   729.0
#
#     infrastructure group_size  \
# 57                      144.0
# 57                      167.0
# 57                      165.0
# 57                      188.0
# 57                      175.0
# ..                        ...
# 0                       158.0
# 0                        98.0
# 0                       105.0
# 0                       103.0
# 0                       120.0
#
#     renewable resources & alternative energy group_size  \
# 57                                               17.0
# 57                                               37.0
# 57                                               22.0
# 57                                               19.0
# 57                                               19.0
# ..                                                ...
# 0                                                 7.0
# 0                                                 3.0
# 0                                                 8.0
# 0                                                 3.0
# 0                                                 9.0
#
#     resource transformation group_size  services group_size  \
# 57                              5333.0               2746.0
# 57                              5036.0               2214.0
# 57                              4754.0               2136.0
# 57                              5841.0               2731.0
# 57                              5258.0               2101.0
# ..                                 ...                  ...
# 0                               6750.0               1710.0
# 0                              10803.0               2456.0
# 0                               8304.0               1964.0
# 0                               8076.0               2372.0
# 0                              10390.0               2251.0
#
#     technology & communications group_size  transportation group_size  \
# 57                                   687.0                      532.0
# 57                                   634.0                      537.0
# 57                                   695.0                      487.0
# 57                                   673.0                      525.0
# 57                                   694.0                      539.0
# ..                                     ...                        ...
# 0                                   1268.0                      361.0
# 0                                   1373.0                      511.0
# 0                                   1186.0                      421.0
# 0                                   1335.0                      341.0
# 0                                   1397.0                      795.0
#
#     Total Articles  Average Tones
# 57         10880.0      -0.728437
# 57         10081.0      -0.779057
# 57          9881.0      -0.589076
# 57         11334.0      -0.881991
# 57         10042.0      -1.107878
# ..             ...            ...
# 0          11262.0      -2.635059
# 0          16527.0      -3.305134
# 0          13477.0      -1.480875
# 0          13129.0      -2.971011
# 0          16055.0      -2.734868
#
# [5337 rows x 27 columns]

# %%
# combine all the CSV files into one DataFrame
dfs = []
for file in files:
    obj = s3.get_object(Bucket=bucket_name, Key=file)
    df = pd.read_csv(obj['Body'])
    dfs.append(df)
combined_df = pd.concat(dfs)

# rename 'total' column to 'Total Articles'
combined_df = combined_df.rename(columns={'total': 'Total Articles'})

# rename 'total_average' column to 'Average Tones'
combined_df = combined_df.rename(columns={'total_average': 'Average Tones'})

# sort the DataFrame by country, year, month in descending order
combined_df = combined_df.sort_values(by=['country', 'Year', 'Month'], ascending=True)

# %%
# create a mapping of old column names to new column names
col_mapping = {col: col.replace('group_size', '- article count').replace('average_tone', '- tone')
               for col in combined_df.columns if col.endswith(('group_size', 'average_tone'))}

# rename the columns using the mapping
combined_df = combined_df.rename(columns=col_mapping)

# reassign the renamed columns to the original dataframe
combined_df.columns = [col_mapping.get(col, col) for col in combined_df.columns]

# %%
combined_df
# Out:
#    country  Month  Year  consumer goods - tone  \
# 0       AG      3  2015                  0.823
# 0       AG      4  2015                  1.881
# 0       AG      5  2015                  1.410
# 0       AG      6  2015                  0.086
# 0       AG      7  2015                 -0.067
# ..     ...    ...   ...                    ...
# 57      ZI      6  2022                  3.218
# 57      ZI      7  2022                  1.705
# 57      ZI      8  2022                  0.098
# 57      ZI      9  2022                  2.571
# 57      ZI     10  2022                 -0.501
#
#     extractives & minerals processing - tone  financials - tone  \
# 0                                     -1.748              1.375
# 0                                     -0.309              1.223
# 0                                     -0.595              0.912
# 0                                     -0.909              1.479
# 0                                     -0.563              0.987
# ..                                       ...                ...
# 57                                     0.969              0.326
# 57                                     1.394              0.436
# 57                                     0.073             -0.011
# 57                                     0.445             -0.616
# 57                                     0.202             -0.355
#
#     food & beverage - tone  health care - tone  infrastructure - tone  \
# 0                    0.842              -2.807                 -0.334
# 0                    1.242              -2.338                  0.086
# 0                    0.819              -1.368                 -2.071
# 0                    0.322              -2.153                 -0.103
# 0                    1.106              -2.343                 -0.049
# ..                     ...                 ...                    ...
# 57                   0.145              -2.150                 -0.225
# 57                   0.592              -1.667                 -0.557
# 57                   0.300              -1.920                  0.397
# 57                   0.249              -1.752                 -0.177
# 57                  -0.200              -1.010                 -0.064
#
#     renewable resources & alternative energy - tone  ...  \
# 0                                             0.410  ...
# 0                                            -0.983  ...
# 0                                             0.786  ...
# 0                                            -0.603  ...
# 0                                            -0.825  ...
# ..                                              ...  ...
# 57                                           -1.024  ...
# 57                                            0.103  ...
# 57                                           -1.334  ...
# 57                                           -0.869  ...
# 57                                           -0.805  ...
#
#     food & beverage - article count  health care - article count  \
# 0                              76.0                        729.0
# 0                              60.0                        637.0
# 0                              70.0                        671.0
# 0                              71.0                        680.0
# 0                              66.0                        725.0
# ..                              ...                          ...
# 57                            183.0                        826.0
# 57                            155.0                        874.0
# 57                            178.0                       1076.0
# 57                            169.0                       1042.0
# 57                            206.0                        960.0
#
#     infrastructure - article count  \
# 0                            120.0
# 0                            103.0
# 0                            105.0
# 0                             98.0
# 0                            158.0
# ..                             ...
# 57                           175.0
# 57                           188.0
# 57                           165.0
# 57                           167.0
# 57                           144.0
#
#     renewable resources & alternative energy - article count  \
# 0                                                 9.0
# 0                                                 3.0
# 0                                                 8.0
# 0                                                 3.0
# 0                                                 7.0
# ..                                                ...
# 57                                               19.0
# 57                                               19.0
# 57                                               22.0
# 57                                               37.0
# 57                                               17.0
#
#     resource transformation - article count  services - article count  \
# 0                                   10390.0                    2251.0
# 0                                    8076.0                    2372.0
# 0                                    8304.0                    1964.0
# 0                                   10803.0                    2456.0
# 0                                    6750.0                    1710.0
# ..                                      ...                       ...
# 57                                   5258.0                    2101.0
# 57                                   5841.0                    2731.0
# 57                                   4754.0                    2136.0
# 57                                   5036.0                    2214.0
# 57                                   5333.0                    2746.0
#
#     technology & communications - article count  \
# 0                                        1397.0
# 0                                        1335.0
# 0                                        1186.0
# 0                                        1373.0
# 0                                        1268.0
# ..                                          ...
# 57                                        694.0
# 57                                        673.0
# 57                                        695.0
# 57                                        634.0
# 57                                        687.0
#
#     transportation - article count  Total Articles  Average Tones
# 0                            795.0         16055.0      -2.734868
# 0                            341.0         13129.0      -2.971011
# 0                            421.0         13477.0      -1.480875
# 0                            511.0         16527.0      -3.305134
# 0                            361.0         11262.0      -2.635059
# ..                             ...             ...            ...
# 57                           539.0         10042.0      -1.107878
# 57                           525.0         11334.0      -0.881991
# 57                           487.0          9881.0      -0.589076
# 57                           537.0         10081.0      -0.779057
# 57                           532.0         10880.0      -0.728437
#
# [5337 rows x 27 columns]

# %%
# write the combined DataFrame to a CSV file
csv_buffer = combined_df.to_csv(index=False)
s3.put_object(Bucket=bucket_name, Key=prefix + 'combined_results.csv', Body=csv_buffer)

print('Combined CSV file saved successfully to S3.')
# Out:
# Combined CSV file saved successfully to S3.
