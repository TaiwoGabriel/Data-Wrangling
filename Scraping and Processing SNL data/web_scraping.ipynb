# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = "https://ppi.worldbank.org/en/resources/ppi-publications#2"

# %%
page = requests.get(url)

# %%
print(page)
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n\n \n \n\n\n\n<!DOCTYPE html>\n<html lang="en">\n     \n\n \n\n\n   \n\n\n\n\n\n\n\n\n\n\n\n\n\n<head>\n    \n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <link rel="shortcut icon" href="/content/dam/wbr-redesign/logos/wbg-favicon.png" type="image/png"/>\n    <meta name="viewport" content="width=device-width"/>\n    <!--<meta http-equiv="content-type" content="text/html; charset=UTF-8"/>-->\n    \n    \n    <meta name="keywords" content=""/>\n    <meta name="description" content=""/> \n    <meta name="language" content="en"/>\n    \n\n    <link rel="canonical" href="https://ppi.worldbank.org/en/resources/ppi-publications"/>\n\n    <link rel="stylesheet" href="/etc/designs/wbrrdesign/clientlibs-ppi.css" type="text/css">\n\n    \n    <link href="//fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i&subset=cyrillic,cyrillic-ext,greek,greek-ext,latin-ext,vietnamese" rel=\'stylesheet\' type=\'text/css\'/>\n\n\n    <title>Publicati
# ...

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/content/dam/wbr-redesign/logos/wbg-favicon.png" rel="shortcut icon" type="image/png"/>
# <meta content="width=device-width" name="viewport"/>
# <!--<meta http-equiv="content-type" content="text/html; charset=UTF-8"/>-->
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# <meta content="en" name="language"/>
# <link href="https://ppi.worldbank.org/en/resources/ppi-publications" rel="canonical"/>
# <link href="/etc/designs/wbrrdesign/clientlibs-ppi.css" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i&amp;subset=cyrillic,cyrillic-ext,greek,greek-ext,latin-ext,vietnamese" rel="stylesheet" type="text/css">
# <title>Publications on Private Participation in Infrastructure (PPI) - World Bank Group</title>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <link href="/content/dam/wbr-redesign/logos/wbg-favicon.png" rel="shortcut icon" type="image/png"/>\n  <meta content="width=device-width" name="viewport"/>\n  <!--<meta http-equiv="content-type" content="text/html; charset=UTF-8"/>-->\n  <meta content="" name="keywords"/>\n  <meta content="" name="description"/>\n  <meta content="en" name="language"/>\n  <link href="https://ppi.worldbank.org/en/resources/ppi-publications" rel="canonical"/>\n  <link href="/etc/designs/wbrrdesign/clientlibs-ppi.css" rel="stylesheet" type="text/css"/>\n  <link href="//fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i&amp;subset=cyrillic,cyrillic-ext,greek,greek-ext,latin-ext,vietnamese" rel="stylesheet" type="text/css">\n   <title>\n    Publications on Private Participation in Infrastructure (PPI) - World Bank Group\n   </title>\n   <!-- <script src="/etc/designs/
# ...

# %%
title = soup.select("h5")
title
# Out:
# [<h5><a href="http://www.oecd.org/officialdocuments/publicdisplaydocumentpdf/?cote=DCD/WKP(2014)1&amp;docLanguage=En">Case Studies on Leveraging Private Investment for Infrastructure</a></h5>,
#  <h5><a href="https://www.emeraldinsight.com/doi/abs/10.1108/17506161211246908">Determinants of PPP in Infrastructure in Developing Economies</a></h5>,
#  <h5><a href="https://ascelibrary.org/doi/full/10.1061/(ASCE)CO.1943-7862.0000333">Drivers of Conflict in Developing Country Infrastructure Projects: Experience from the Water and Pipeline Sectors</a></h5>,
#  <h5><a href="http://www.oecd-ilibrary.org/docserver/download/5jrw2xzj0m7l-en.pdf?expires=1502338603&amp;id=id&amp;accname=guest&amp;checksum=A0D6477107F06E0821D41A50177B4A32">Institutional and Political Determinants of Private Participation in Infrastructure</a></h5>,
# ...

# %%
ls_link= []
ls_title=[]
for i in title[22:]:
    ls_link.append(i.a.get('href'))
    ls_title.append(i.a.get_text())

# %%
print(len(ls_link))
ls_link
# Out:
# 130
# ['https://www.tandfonline.com/doi/abs/10.1080/03003930.2013.782859',
#  'https://www.sciencedirect.com/science/article/pii/S0301421511003399',
#  '/content/dam/PPI/resources/ppi_publication/global/12.pdf',
#  'https://ascelibrary.org/doi/abs/10.1061/(ASCE)ME.1943-5479.0000213',
#  'http://www.arsa-conf.com/archive/?vid=1&aid=3&kid=60201-58&q=f1.',
#  'http://sci-hub.io/10.1016/j.jup.2015.06.005',
#  'http://idbdocs.iadb.org/wsdocs/getDocument.aspx?DOCNUM=39560897',
#  'https://www.tandfonline.com/doi/full/10.1080/00220388.2014.959935',
#  'https://publications.iadb.org/bitstream/handle/11319/6016/int3F8F.PDF?sequence=1&isAllowed=y',
#  'http://leitner.yale.edu/sites/default/files/files/resources/papers/PostMurilloYaleJan.7.2014.pdf',
#  'http://www.econjournals.com/index.php/ijeep/article/view/2765',
#  'http://www.indiawaterportal.org/sites/indiawaterportal.org/files/review_of_cancellation_of_ppp_projects_in_india.pdf',
#  'https://doi-org/10.1177/097493061100300102',
# ...

# %%
print(len(ls_title))
ls_title
# Out:
# 130
# ['Local Public-Services Provision under Public–Private Partnerships: Contractual Design and Contracting Parties Incentives',
#  'Political Institutions of Electricity Regulation: The Case of Turkey',
#  'Political Institutions of Electricity Regulation: The Case of Turkey Project Finance and Projects in the Energy Sector in Developing Countries',
#  'Public-Private Partnership Experience in the International Arena: Case of Turkey',
#  'Role of Public Private Partnership in Infrastructure Development (Focus on Albania)',
#  'Turkish experience with public private partnerships in infrastructure: Opportunities and challenges',
#  'Evaluating the Environment for Public-Private Partnerships in Latin America and the Caribbean: The 2014 Infrascope',
#  'Infrastructure Public-Private Partnerships in the Developing World: Lessons from Recent Experience',
#  'Privatization, Institutional Reform, and Performance in the Latin American Electricity Sector',
# ...

# %%
content = soup.select("div>p")
content
# Out:
# [<p>Since its creation, the PPI Database has been the main information source for trends in private participation in infrastructure in developing countries for a large number of publications. The list below contain publications that rely on data from the PPI Database. If you have any publications that you would like featured on this page, please email them to us at <a href="mailto:dsaha1@worldbank.org">dsaha1@worldbank.org</a></p>,
#  <p><b>Source:</b> Development Co-operation Directorate Working Paper, OECD Publishing.</p>,
# ...

# %%
ls_abstract = []
ls_publication = []
for i in content[1:]:
    if len(i.contents)==2:
        ls_publication.append(i.contents[1])
    else: 
        ls_abstract.append(i.contents[0])
ls_publication
# Out:
# [' Development Co-operation Directorate Working Paper, OECD Publishing.',
#  ' Transforming Government: People, Process and Policy 6 (2): 149–66.',
#  ' Journal of Construction Engineering and Management 137 (7): 498–511.',
#  ' Discussion Paper No 2014-15. Prepared for the Roundtable: Public Private Partnerships for Transport Infrastructure: Renegotiations, how to approach them and economic outcomes. 27-28 October 2014, George Mason University, Washington D.C., USA..',
#  'LSE Asia Research Centre Working Paper 87.',
#  ' Comparative Political Studies 44 (6): 771–803.',
#  ' Journal of World Business 50 (2): 294–301.',
#  ' International Journal of Urban and Regional Research 37 (4): 1254–72.',
#  ' Organization Science 17 (3): 402–14.',
#  ' Urban Transport XXI, 146: 399–410',
#  ' Public Performance & Management Review 40 (2): 431–55.',
#  ' MPRA Paper. University Library of Munich, Germany.',
#  '\xa0Advanced Materials Research 869–870: 488–94.',
# ...

# %%
print(len(ls_abstract))
ls_abstract
# Out:
# 130
# ['This paper provides an overview of infrastructure projects with private investment in infrastructure based on data extracted from the World Bank PPI database. The data analysis by number of infrastructure projects with private participation shows that two thirds of projects are supported by multilateral development banks only. In terms of income levels, there is little support to projects in low-income countries, but the support is more or less equally divided between lower middle income countries and upper middle income countries.',
# ...

# %%
print(len(ls_publication))
ls_publication
# Out:
# 118
# [' Development Co-operation Directorate Working Paper, OECD Publishing.',
#  ' Transforming Government: People, Process and Policy 6 (2): 149–66.',
#  ' Journal of Construction Engineering and Management 137 (7): 498–511.',
#  ' Discussion Paper No 2014-15. Prepared for the Roundtable: Public Private Partnerships for Transport Infrastructure: Renegotiations, how to approach them and economic outcomes. 27-28 October 2014, George Mason University, Washington D.C., USA..',
#  'LSE Asia Research Centre Working Paper 87.',
#  ' Comparative Political Studies 44 (6): 771–803.',
#  ' Journal of World Business 50 (2): 294–301.',
#  ' International Journal of Urban and Regional Research 37 (4): 1254–72.',
#  ' Organization Science 17 (3): 402–14.',
#  ' Urban Transport XXI, 146: 399–410',
#  ' Public Performance & Management Review 40 (2): 431–55.',
#  ' MPRA Paper. University Library of Munich, Germany.',
#  '\xa0Advanced Materials Research 869–870: 488–94.',
# ...
